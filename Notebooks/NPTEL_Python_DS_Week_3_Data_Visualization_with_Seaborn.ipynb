# %% [markdown]
# ## Seaborn
#
# * Seaborn is a Python data visualization library
# based on matplotlib
# * It provides a high-level interface for drawing
# attractive and informative statistical graphics

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

os.chdir('D:\\Downloads\\Datasets\\NPTEL')

# %%
cars_data = pd.read_csv('Toyota.csv',index_col=0, na_values=["??","????"])
cars_data.shape
# Out:
# (1436, 10)

# %%
cars_data.dropna(axis=0, inplace=True)

# %%
cars_data.shape
# Out:
# (1096, 10)

# %%
sns.set(style='darkgrid')
sns.regplot(x=cars_data['Age'], 
            y=cars_data['Price'], 
            fit_reg=False,
            marker='.') # Regression plot, performs a Scatter plot

# %% [markdown]
# ### Scatter plot of Price vs Age by FuelType
# Using hue parameter, including another variable to show the fuel
# types categories with different colors

# %%
sns.lmplot(x='Age',
          y='Price',
          data=cars_data,
          fit_reg=False,
          hue="FuelType",
          legend=True,
          palette='Set1')

# %% [markdown]
# ## Histogram
#
# * Histogram with default kernel density estimate

# %%
sns.distplot(cars_data['Age'])

# %% [markdown]
# * Histogram 'without kernel density estimate

# %%
sns.distplot(cars_data['Age'], kde=False)

# %%
sns.distplot(cars_data['Age'], 
             kde=False,
             bins=10)

# %% [markdown]
# ## Bar Plot
#
# * Frequency distribution of fuel type of the cars

# %%
sns.countplot(x="FuelType", data=cars_data)

# %% [markdown]
# ## Grouped Bar Plot
#
# Grouped bar plot of FuelType and Automatic

# %%
sns.countplot(x='FuelType', 
              data=cars_data, 
              hue="Automatic")

# %% [markdown]
# ## Box and whiskers plot - numerical variable
#
# Box and whiskers plot of Price to visually interpret the
# five-number summary

# %%
sns.boxplot(y=cars_data['Price'])

# %% [markdown]
# * Box and whiskers plot for numerical vs categorical variable
# * Price of the cars for various fuel types

# %%
sns.boxplot(x=cars_data['FuelType'], y=cars_data['Price'])

# %% [markdown]
# ## Grouped box and whiskers plot
# * Grouped box and whiskens plot of Price vs FuelType and Automatic

# %%
sns.boxplot(x='FuelType', 
            y='Price', 
            data=cars_data,
            hue='Automatic')

# %% [markdown]
# ## Box-whiskers plot and Histogram
# * Let’s plot box-whiskers plot and histogram on the same window
# * Split the plotting window into 2 parts

# %%
f,(ax_box, ax_hist)=plt.subplots(2,
                                gridspec_kw={
                                    "height_ratios": (.15, .85)
                                })

# %% [markdown]
# Now, add create two plots

# %%
sns.boxplot(x=cars_data['Price'], ax=ax_box)
sns.distplot(cars_data['Price'], ax=ax_hist, kde=False)
plt.show()

# %% [markdown]
# ## PairWise plots
# * It is used to plot pairwise relationships in a dataset
# * Creates scatterplots for joint relationships and histograms for univariate distributions

# %%
sns.pairplot(cars_data,
            kind="scatter",
            hue="FuelType")

plt.show()
# Out:
# C:\Users\karan\AppData\Roaming\Python\Python37\site-packages\seaborn\distributions.py:288: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\karan\AppData\Roaming\Python\Python37\site-packages\seaborn\distributions.py:288: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\karan\AppData\Roaming\Python\Python37\site-packages\seaborn\distributions.py:288: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
